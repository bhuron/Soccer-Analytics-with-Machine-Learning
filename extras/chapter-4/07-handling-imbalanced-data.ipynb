# %% [markdown]
# # Handling Imbalanced Data (EXTRA)
#
# **Chapter 4**
#
# ## Learning Objectives
# - Understand class imbalance
# - Use appropriate metrics
# - Apply resampling techniques
# - Adjust class weights

# %%
import pandas as pd
from sklearn.utils import resample
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## The Problem
#
# In soccer:
# - ~12% of shots are goals
# - ~88% are not goals
#
# A model predicting "No Goal" always gets 88% accuracy but is useless!

# %% [markdown]
# ## Solutions
#
# ### 1. Use Better Metrics
# - Precision, Recall, F1, AUC
# - Don't rely on accuracy alone
#
# ### 2. Class Weights
# ```python
# clf = LogisticRegression(class_weight='balanced')
# ```
#
# ### 3. Resampling
# - Oversample minority class
# - Undersample majority class
#
# ### 4. Adjust Threshold
# - Lower threshold to catch more positives

# %% [markdown]
# ## Summary
#
# - Imbalanced data is common in soccer
# - Use appropriate metrics
# - Several techniques available
# - Choose based on your problem
