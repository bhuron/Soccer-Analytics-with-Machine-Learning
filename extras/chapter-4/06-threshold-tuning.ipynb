# %% [markdown]
# # Decision Threshold Tuning (EXTRA)
#
# **Chapter 4**
#
# ## Learning Objectives
# - Understand decision thresholds
# - Find optimal threshold for different goals
# - Balance precision vs recall

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

# %% [markdown]
# ## What is a Decision Threshold?
#
# By default, we use 0.5:
# - Probability ≥ 0.5 → Predict "Goal"
# - Probability < 0.5 → Predict "No Goal"
#
# But we can adjust this!

# %% [markdown]
# ## Precision-Recall Trade-off
#
# - **Lower threshold** (e.g., 0.3): More aggressive, higher recall, lower precision
# - **Higher threshold** (e.g., 0.7): More conservative, higher precision, lower recall

# %% [markdown]
# ## Finding Optimal Threshold
#
# Try different thresholds and plot metrics.
#
# See book for full code.

# %% [markdown]
# ## Summary
#
# - Threshold affects precision/recall balance
# - F1-score helps find optimal threshold
# - Choose based on your use case
